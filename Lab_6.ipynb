# %% [markdown]
# <a href="https://colab.research.google.com/github/TejaswiniKashireddy/RL_2026/blob/main/Lab_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gymnasium as gym

def random_agent(env_name, episodes=5):
    env = gym.make(env_name)

    for episode in range(1, episodes + 1):
        state, info = env.reset()
        total_reward = 0
        steps = 0
        terminated = False
        truncated = False

        while not (terminated or truncated):
            action = env.action_space.sample()
            next_state, reward, terminated, truncated, info = env.step(action)

            total_reward += reward
            steps += 1
            state = next_state

        average_reward = total_reward / steps

        print("Episode:", episode)
        print("Total Reward:", total_reward)
        print("Average Reward:", round(average_reward, 2))
        print()

    env.close()

print("CliffWalking Environment")
random_agent("CliffWalking-v1", 5)

print("Taxi Environment")
random_agent("Taxi-v4", 5)
# Out:
# CliffWalking Environment
# Episode: 1
# Total Reward: -194452
# Average Reward: -10.72
#
# Episode: 2
# Total Reward: -62710
# Average Reward: -11.03
#
# Episode: 3
# Total Reward: -37116
# Average Reward: -10.44
#
# Episode: 4
# Total Reward: -17788
# Average Reward: -10.77
#
# Episode: 5
# Total Reward: -15014
# Average Reward: -11.11
#
# Taxi Environment
# Episode: 1
# Total Reward: -983
# Average Reward: -4.92
#
# Episode: 2
# Total Reward: -812
# Average Reward: -4.06
#
# Episode: 3
# Total Reward: -848
# Average Reward: -4.24
#
# Episode: 4
# Total Reward: -722
# Average Reward: -3.61
#
# Episode: 5
# Total Reward: -812
# Average Reward: -4.06
